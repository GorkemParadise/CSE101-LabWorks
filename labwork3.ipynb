# %%
#Task 1 : Train Ticket

destination = "Izmir"
seat_number = 14
ticket_price = 220.5

print(f"Ticket to {destination} - Seat: {seat_number} - Price: {ticket_price}")
# Out:
# Ticket to Izmir - Seat: 14 - Price: 220.5

# %%
#Task 2 : Grocery List

apple = 15
bread = 10
milk = 22
total = apple + bread + milk
print(f"Total cost: {total}")
# Out:
# Total cost: 47

# %%
#Task 3 : Music Playlist

song1 = 3.5
song2 = 4.2
total = song1 + song2
print(f"Total min: {total}")
# Out:
# Total min: 7.7

# %%
#Task 4 : Phone Bil

call_minutes = 150
internet_gb = 8
base_fee = 100

total = base_fee + (call_minutes * 0.5) + (internet_gb * 10)

print(total)
# Out:
# 255.0

# %%
#Task 5 : Library Books

borrowed_books = 3
due_days = 7

print(f"You borrowed {borrowed_books} books. Please return them in {due_days} days.")
# Out:
# You borrowed 3 books. Please return them in 7 days.

# %%
#Task 6 : Fuel Cost

distance_km = 320
uel_consumption_per_km = 0.08
uel_price_per_liter = 43.5

total = distance_km/uel_consumption_per_km*uel_price_per_liter
print(total)
# Out:
# 174000.0

# %%
#Task 7 : Gym Membership

months = 6
price_per_month = 450
discount = 0.1

total = price_per_month - months*discount

print(total)
# Out:
# 449.4

# %%
#Task 8 : Laptop Battery

battery = 15
if battery < 20:
    print("Please charge your laptop")
else:
    print("Good")
# Out:
# Please charge your laptop

# %%
#Task 9 : Student Attendance

attendance = 82
if attendance >= 70:
    print("Attendance sufficient.")
else:
    print("Attendance is low.")
# Out:
# Attendance sufficient.

# %%
#Task 10 : Package Weight

weight = 8
if weight > 10:
    print("Extra charge applies.")
else:
    print("Nothing")
# Out:
# Nothing

# %%
#Task 11 : Internet Speed

speed = 52
if speed > 50:
    print("High-speed connection.")
else:
    print("Low speed")
# Out:
# High-speed connection.

# %%
#Task 12 : Exam Average

midterm = 75
final = 68
Calculate = (midterm * 0.4) + (final * 0.6)
print(Calculate)
# Out:
# 70.8

# %%
#Task 13 : Rain Check

is_raining = False
temperature = 22
if is_raining == True:
    if temperature < 15:
        print("Take an umbrella!")
    else: 
        print("Don’t forget a jacket.")
else:
    print("Enjoy your day!")
# Out:
# Enjoy your day!

# %%
#Task 14 : Movie Discount

age = 16
is_student = True

if age < 18 and is_student == True:
    print("You get a youth discount!")
else:
    print("Standard ticket price.")
# Out:
# You get a youth discount!

# %%
#Task 15 : Air Quality

aqi = 130.

if aqi > 150:
    print("Unhealthy air!")
elif aqi > 100:
    print("Moderate air quality.")
else: 
    print("Good air quality.")
# Out:
# Moderate air quality.

# %%
#Task 16 : Shopping Discount

total_price = 280
is_member = True

if is_member == True:
    if total_price > 200:
        print("25% discount applied!")
    else:
        print("10% discount applied!")
else:
    print("No discount.")
# Out:
# 25% discount applied!

# %%
#Task 17 : Cinema Snacks

popcorn = 55
drink = 25
has_coupon = True
total = popcorn + drink

if has_coupon == True:
    total = total*75/100
print(total)
# Out:
# 60.0

# %%
#Task 18 : Bus Fare

distance_km = 18
base_fare = 10
per_km = 1.5
total = distance_km * per_km

if distance_km > 15:
    total = total * 9/10
print(total)
# Out:
# 24.3

# %%
#Task 19 : Room Temperature Control

temp = 19.

if temp <18:
    print("Heater ON")
elif temp > 25:
    print("Air conditioner ON")
else: 
    print("Temperature is comfortable.")
# Out:
# Temperature is comfortable.

# %%
#Task 20 : Package Delivery

delivered = False
days_waited = 3

if delivered == False:
    if days_waited > 5:
        print ("Please contact support!")
    else:
        print("Your package is on the way.")
else:
    print("Package received.")
# Out:
# Your package is on the way.

# %%
#Task 21 : Exam Evaluation

score = 9

if score >= 90:
    print("Excellent")
elif score >= 75:
    print( "Good")
else:
    print("Fail")
# Out:
# Fail

# %%
#Task 22 : Smartwatch Steps

steps_today = 9300
goal = 10000
total = goal - steps_today

if total >= goal:
    print("Goal reached!")
else:
    print(f"Reamin: {total} steps")
# Out:
# Reamin: 700 steps

# %%
#Task 23 : Water Reminder

glasses_drunk = 4
total = 8 -int(glasses_drunk)

if glasses_drunk < 8:
    print(f"Need: {total}")
else:
    print("You met your hydration goal!")
# Out:
# Need: 4

# %%
#Task 24 : Store Opening

current_hour = 21
opening_hour = 9
closing_hour = 22

if current_hour > opening_hour and current_hour < closing_hour:
    print("Store is open.")
else:
    print("Closed")
# Out:
# Store is open.

# %%
#Task 25 : Flight Status

delay_minutes = 45.

if delay_minutes <15:
    print("On time.")
elif delay_minutes <60:
    print("Slight delay.")
else:
    print("Major delay.")
# Out:
# Slight delay.

# %%
#Task 26 : Car Wash

is_raining = False
day = "Saturday"

if is_raining == True:
    print("Car wash canceled.")
else:
    if day == "Saturday": 
        print("Weekend wash discount applied!")
# Out:
# Weekend wash discount applied!

# %%
#Task 27 : Hotel Booking

nights = 4
price_per_night = 750
breakfast_included = True
total = nights * price_per_night
extra = 150

if breakfast_included == True:
    total = total + (nights * 150)
    print(total)
else:
    print(total)
# Out:
# 3600

# %%
#Task 28 : Fitness Goal

calories_burned = 420
goal = 500
dif = goal - calories_burned

if calories_burned >= goal:
    print("Goal completed!")
else:
    print(dif)
# Out:
# 80

# %%
#Task 29 : Light Control

is_daytime = False
motion_detected = True

if is_daytime == False and motion_detected == True:
    print("Turn on lights.")
else:
    print("Lights off.")
# Out:
# Turn on lights.

# %%
#Task 30 : Parcel Tracking

status = "In Transit"

if status == "In Transit":
    print("Your parcel is on the way.")
elif status == "Delivered":
    print("Your parcel has arrived.")
else:
    print("Awaiting shipment.")
# Out:
# Your parcel is on the way.

# %%
#Task 31 : Course Progress

progress = 78.

if progress >= 100:
    print("Course completed!")
elif progress >= 75:
    print("Almost done!")
elif progress >= 50:
    print("Halfway there!")
else:
    print("Just getting started.")
# Out:
# Almost done!

# %%
#Task 32 : Electricity Bill

usage_kwh = 340
rate = 1.25
total = usage_kwh * rate

if total > 300:
    total = total * 1.10
    print(total)
else:
    print(total)
# Out:
# 467.50000000000006

# %%
#Task 33 : Online Order Rating

rating = 4.3

if rating >= 4.5:
    print("Excellent service!")
elif rating >= 3.5:
    print("Good service!")
else:
    print("Needs improvement.")
# Out:
# Good service!

# %%
#Task 34 : Weather Advisory

temperature = 35
humidity = 80

if temperature > 30 and humidity > 70:
    print("Heat warning!")
else:
    print("Weather conditions normal.")
# Out:
# Heat warning!

# %%
#Task 35 : Password Strength

password_length = 9.

if password_length >= 12:
    print("Strong password")
elif password_length >= 8:
    print("Medium password")
else:
    print("Weak password")
# Out:
# Medium password

# %%
#Task 36 : Smart Home Energy Control

temperature = 28
sunlight = True
occupants = 0

if occupants == 0:
    print("Turn off lights and air conditioning.")
if temperature > 26 and sunlight == True:
    print("Activate eco-cooling mode.")
else:
    print("System idle.")
# Out:
# Turn off lights and air conditioning.
# Activate eco-cooling mode.

# %%
#Task 37 : Drone Delivery Battery

battery_level = 35
distance_km = 8

if battery_level < 30:
    print("Return to base!")
    if distance_km > 10:
        print("Too far for current battery!")
else:
    print("Delivery in progress.")
# Out:
# Delivery in progress.

# %%
#Task 38 : Restaurant Order System

items_ordered = 4
total_cost = 420
has_coupon = True

if has_coupon == True and total_cost > 300:
    total_cost = total_cost * 0.8
    print(total_cost)
if items_ordered > 5:
    print("Free dessert added!")
# Out:
# 336.0

# %%
#Task 39 : Scholarship Eligibility

gpa = 3.45
community_service_hours = 42
attendance = 95

if gpa >= 3.5 and attendance >= 90:
    print("Eligible for full scholarship.")
elif gpa >= 3.0 and community_service_hours >= 40:
    print("Eligible for partial scholarship.")
else:
    print("Not eligible.")
# Out:
# Eligible for partial scholarship.

# %%
#Task 40 : Smart Refrigerator

milk_liters = 0.3
eggs = 4
groceries_budget = 200

if milk_liters < 0.5 or eggs < 6:
    print("Restock needed.")
if groceries_budget < 150:
    print("Low budget warning.")
# Out:
# Restock needed.

# %%
#Task 41 : Flight Upgrade

miles = 12500
membership_years = 3

if miles  > 10000 and membership_years >= 2:
    print("Eligible for seat upgrade.")
else:
    print("Keep collecting miles!")
# Out:
# Eligible for seat upgrade.

# %%
#Task 42 : Weather-Based Clothing

temperature = 14
raining = True
wind_speed = 22

if raining == True and temperature < 18:
    print("Wear waterproof jacket and boots.")
else:
    if temperature > 25: 
        print("Light clothes recommended.")
    else:
        if wind_speed > 20:
            print("Don’t forget a windbreaker.")
# Out:
# Wear waterproof jacket and boots.

# %%
#Task 43 : Warehouse Inventory

item_count = 145
reorder_threshold = 150
urgent_orders = True

if item_count < reorder_threshold and urgent_orders == True:
    print("Reorder immediately!")
else:
    if item_count < reorder_threshold:
        print("Schedule restock.")
    else:
        print("Stock sufficient.")
# Out:
# Reorder immediately!

# %%
#Task 44 : Fitness Tracker Goals

steps = 11200
calories = 550
active_minutes = 42

if steps >= 10000 and calories >= 500 and active_minutes >= 30:
    print("Full goal achieved!")
else:
    if steps >= 10000 or calories >= 500 and active_minutes >= 30:
        print("Good job!")
    elif steps >= 10000 and calories >= 500 or active_minutes >= 30:
        print("Good job!")
    else:
        print("Keep moving!")
# Out:
# Full goal achieved!

# %%
#Task 45 : Online Course Completion

lessons_completed = 18
total_lessons = 20
quiz_score = 82

if lessons_completed == total_lessons and quiz_score >= 80:
    print("Course completed with certificate.")
else:
    if lessons_completed < total_lessons:
        print("Keep learning!")
    else:
        print("Needs higher quiz score.")
# Out:
# Keep learning!

# %%
#Task 46 : Water Usage Alert

usage_liters = 780
limit = 700
city_restriction = True

if usage_liters > limit and city_restriction:
    print("Penalty: Over limit during restriction!")
else:
    if usage_liters > limit:
        print("Warning: Reduce water usage!")
    else:
        print("Within safe range.")
# Out:
# Penalty: Over limit during restriction!

# %%
#Task 47 : Bank Transaction Security

transaction_amount = 9500
is_verified_user = False
location_match = False

if transaction_amount > 5000 and is_verified_user == False:
    print("Transaction blocked!")
else:
    if location_match == False:
        print("Verify login location.")
    else:
        print("Transaction successful.")
# Out:
# Transaction blocked!

# %%
#Task 48 : Taxi Fare Estimation

distance = 12.5
base_fare = 30
per_km = 8
night_rate = True
fare = base_fare + (distance * per_km)

if night_rate:
    fare = fare * 1.25
if distance > 20:
    fare = fare * 0.9
print(fare)
# Out:
# 162.5

# %%
#Task 49 : Hospital Room Assignment

patient_age = 72
requires_isolation = True
available_private_rooms = 2

if requires_isolation == True:
    print("Assign private room.")
else:
    if patient_age > 65 and available_private_rooms > 0:
        print("Assign comfort room.")
    else:
        print("Assign standard ward.")
# Out:
# Assign private room.

# %%
#Task 50 : E-commerce Return Policy

days_since_purchase = 18
item_condition = "Opened"
is_member = True

if days_since_purchase <= 15:
    print("Return accepted.")
else:
    if days_since_purchase <= 30 and is_member == True and item_condition == "Opened":
        print("Partial refund available.")
    else:
        print("Return not accepted.")
# Out:
# Partial refund available.
