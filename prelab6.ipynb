# %%
# 1
def add(a, b):
    result = a + b
    return result 
add(5, 6)
# Out:
# 11

# %%
# 2
numbers = []
for value in (5, 10, 15):
    numbers.append(value)
    grades = {"math": 92, "cs": 88}
    colors = {"red", "green", "blue"}
    print("numbers", numbers, "len:", len(numbers))
    print("grades", grades, "len:", len(grades))
    print("colors", colors, "len:", len(colors))
# Out:
# numbers [5] len: 1
# grades {'math': 92, 'cs': 88} len: 2
# colors {'green', 'blue', 'red'} len: 3
# numbers [5, 10] len: 2
# grades {'math': 92, 'cs': 88} len: 2
# colors {'green', 'blue', 'red'} len: 3
# numbers [5, 10, 15] len: 3
# grades {'math': 92, 'cs': 88} len: 2
# colors {'green', 'blue', 'red'} len: 3
